# %% [markdown]
# <a href="https://colab.research.google.com/github/LndrJy/Handwritten-Digit-Recognition-System/blob/Phase-1-branch/phase1_data_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')
REPO = "LndrJy/Handwritten-Digit-Recognition-System"

# !git clone https://oauth2:{GITHUB_TOKEN}@github.com/{REPO}.git
# %cd Handwritten-Digit-Recognition-System
# !git checkout Phase-1-branch

# %%
# !pip install -r requirements.txt -q

# %%
import torch
print(f"GPU available : {torch.cuda.is_available()}")
print(f"Device        : {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")
print(f"PyTorch       : {torch.__version__}")

# %%
import sys
sys.path.append('/content/handwriting-engine')

from src.data_pipeline import build_pipeline

train_loader, val_loader, test_loader, manifest = build_pipeline(
    data_dir='data/raw',
    processed_dir='data/processed',
    num_workers=2
)

# %%
# !python -m pytest tests/test_data_pipeline.py -v

# %%
# !git config user.email "your@email.com"
# !git config user.name "Your Name"
# !git add notebooks/phase1_data_pipeline.ipynb data/processed/
# !git commit -m "Phase 1: data pipeline complete, manifest saved"
# !git push
