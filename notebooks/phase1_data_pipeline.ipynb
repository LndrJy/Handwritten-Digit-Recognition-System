# %% [markdown]
# <a href="https://colab.research.google.com/github/LndrJy/Handwritten-Digit-Recognition-System/blob/Phase-1-branch/notebooks/phase1_data_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')
REPO = "LndrJy/Handwritten-Digit-Recognition-System"

# !git clone https://oauth2:{GITHUB_TOKEN}@github.com/{REPO}.git
# %cd Handwritten-Digit-Recognition-System
# !git checkout Phase-1-branch
# Out:
# Cloning into 'Handwritten-Digit-Recognition-System'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 43 (delta 15), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 21.62 KiB | 5.40 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# /content/Handwritten-Digit-Recognition-System
# Branch 'Phase-1-branch' set up to track remote branch 'Phase-1-branch' from 'origin'.
# Switched to a new branch 'Phase-1-branch'

# %%
# !pip install -r requirements.txt -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 106.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 90.4 MB/s eta 0:00:00

# %%
import torch
print(f"GPU available : {torch.cuda.is_available()}")
print(f"Device        : {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")
print(f"PyTorch       : {torch.__version__}")
# Out:
# GPU available : True
# Device        : Tesla T4
# PyTorch       : 2.10.0+cu128

# %%
import sys
sys.path.append('/content/handwriting-engine')

from src.data_pipeline import build_pipeline

train_loader, val_loader, test_loader, manifest = build_pipeline(
    data_dir='data/raw',
    processed_dir='data/processed',
    num_workers=2
)
# Out:
# ...
#   Phase 1 — Data Engineering Pipeline
# ...
#
# [1/5] Loading datasets...
#   Loading MNIST (train)...
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 20.7MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 498kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.59MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.96MB/s]
#     60,000 samples, 10 classes (digits 0-9)
#   Loading MNIST (test)...
#     10,000 samples, 10 classes (digits 0-9)
#   Loading EMNIST ByClass (train)...
# 100%|██████████| 562M/562M [00:03<00:00, 170MB/s]
#     697,932 samples, 62 classes
#   Loading EMNIST ByClass (test)...
#     116,323 samples, 62 classes
#
# [2/5] Merging MNIST + EMNIST...
#   Merged dataset: 757,932 total samples
#   Merged dataset: 126,323 total samples
#
# [3/5] Splitting into train / val / test...
#   Split → train: 606,346 | val: 75,793 | test: 75,793
#   Split → train: 606,346 | val: 75,793 | test: 75,793
#
# [4/5] Building DataLoaders...
#   Batches → train: 4,737 | val: 593 | test: 987
#
# ...

# %%
# !python -m pytest tests/test_data_pipeline.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/Handwritten-Digit-Recognition-System
# plugins: langsmith-0.7.30, typeguard-4.5.1, anyio-4.13.0
# collected 12 items
#
# tests/test_data_pipeline.py::test_label_map_digits PASSED                [  8%]
# tests/test_data_pipeline.py::test_label_map_uppercase PASSED             [ 16%]
# tests/test_data_pipeline.py::test_label_map_lowercase PASSED             [ 25%]
# tests/test_data_pipeline.py::test_label_map_total_classes PASSED         [ 33%]
# tests/test_data_pipeline.py::test_train_transform_output_shape PASSED    [ 41%]
# tests/test_data_pipeline.py::test_eval_transform_output_shape PASSED     [ 50%]
# tests/test_data_pipeline.py::test_transform_normalization_range PASSED   [ 58%]
# tests/test_data_pipeline.py::test_transform_dtype PASSED                 [ 66%]
# ...

# %%
# !git config user.email "leanderjayyy@gmail.com"
# !git config user.name "Leander Jay"
# !git add data/processed/dataset_manifest_v1.0.0.json
# !git commit -m "Phase 1: dataset manifest saved"
# !git push
# Out:
# fatal: pathspec 'notebooks/phase1_data_pipeline.ipynb' did not match any files
# On branch Phase-1-branch
# Your branch is up to date with 'origin/Phase-1-branch'.
#
# nothing to commit, working tree clean
# Everything up-to-date
